# %%
import sys
reflex_project_path = "/home/reflex/refleX/src" 
sys.path.append(reflex_project_path)

# %%
# %load_ext autoreload
# %autoreload 2

import os
import cv2 as cv
import time
import bz2
import numpy as np
import pandas as pd
import random
from matplotlib import pyplot as plt

from rawdatalib import RawDataFile
from preprocessinglib import calculate_center, find_ray_angle, center_visualization, logarithmize, logarithmize_old
from radial_compressor import main_external_call, make_ray_mask
import util as util

# %%
images_path = "/home/reflex/refleX/metadata/6K/original512"
images = os.listdir(images_path)

# %%
best = [2446]
for img_id in best:
    img_path = os.path.join(images_path, images[img_id])
    print(img_path)
    image = cv.imread(img_path, 0)
    center_max = center_visualization(image)
    #center_min = center_visualization(image)
    
    f, (ax1) = plt.subplots(1, 1, sharey=True, figsize=(16, 16))
    ax1.imshow(center_max)
    #ax2.imshow(center_min)

plt.figure(figsize=(12, 12))
plt.imshow(image, cmap='gray')
# Out:
# /home/reflex/refleX/metadata/6K/original512/263060g10_x0001.png

# %%
img_path = os.path.join(images_path, images[2446])
image = cv.imread(img_path, 0)
center_max = center_visualization(image)
cv.imwrite('/home/reflex/tmp/hello.png', center_max)
# Out:
# True

# %%
plt.imshow(image, cmap='gray')

# %%
image_log = logarithmize_old(image)
plt.imshow(image_log, cmap='gray')
