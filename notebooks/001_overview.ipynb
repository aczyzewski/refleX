# %%
# %load_ext autoreload
# %autoreload 2

# %%
import sys
sys.path.insert(0, '..')

# %%
import os

# %%
import pandas as pd
from PIL import Image

# %%
from src.visualisation import make_grid
import src.utils as utils

# %%
# CONSTANTS
DATA_PATH = '../data/'
IMAGES_PATH = os.path.join(DATA_PATH, 'images')
LABELS_PATH = os.path.join(DATA_PATH, 'labels.csv')

# %% [markdown]
# # IMAGES

# %%
images = [os.path.join(IMAGES_PATH, img_name) 
          for img_name in os.listdir(IMAGES_PATH)]

# %%
print(f'Number of images: {len(images)}')
# Out:
# Number of images: 6311

# %%
make_grid(images[:16], (4, 4))

# %% [markdown]
# # LABELS

# %%
labels = pd.read_csv(LABELS_PATH)
labdict = utils.dftodict(labels, 'image')
